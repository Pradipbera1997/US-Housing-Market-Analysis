# %% [markdown]
# #  Factors Analysis of Demand & Supply of US Housing Market

# %%
# import require library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# import dataset
df=pd.read_csv('US_Housing_Demand_&_Supply_Data.csv')

# %%
df.head()
# Out:
#          DATE  Total Construction Spending  House Start  House Permit  \
# 0  01-01-2000                   2388136000         4977          5070
# 1  01-04-2000                   2405182000         4760          4712
# 2  01-07-2000                   2403466000         4511          4664
# 3  01-10-2000                   2447670000         4632          4734
# 4  01-01-2001                   2456183000         4815          5014
#
#    Houses Sold  Supply to Sales Ratio  Mortgage Rate  Unemployment Rate  \
# 0          247               4.300000       8.258333           4.033333
# 1          248               4.533333       8.318500           3.933333
# 2          253               4.166667       8.029000           4.000000
# 3          263               3.933333       7.640667           3.900000
# 4          240               3.766667       7.011500           4.233333
#
#            GDP  Per Capita Income  Home Price Index
# 0  10002179000             30.015        101.339333
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   DATE                         90 non-null     object
#  1   Total Construction Spending  90 non-null     int64
#  2   House Start                  90 non-null     int64
#  3   House Permit                 90 non-null     int64
#  4   Houses Sold                  90 non-null     int64
#  5   Supply to Sales Ratio        90 non-null     float64
#  6   Mortgage Rate                90 non-null     float64
#  7   Unemployment Rate            90 non-null     float64
#  8   GDP                          90 non-null     int64
#  9   Per Capita Income            90 non-null     float64
#  10  Home Price Index             90 non-null     float64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 7.9+ KB

# %%
from datetime import datetime

# %%
df['DATE'] = pd.to_datetime(df['DATE'],dayfirst=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   DATE                         90 non-null     datetime64[ns]
#  1   Total Construction Spending  90 non-null     int64
#  2   House Start                  90 non-null     int64
#  3   House Permit                 90 non-null     int64
#  4   Houses Sold                  90 non-null     int64
#  5   Supply to Sales Ratio        90 non-null     float64
#  6   Mortgage Rate                90 non-null     float64
#  7   Unemployment Rate            90 non-null     float64
#  8   GDP                          90 non-null     int64
#  9   Per Capita Income            90 non-null     float64
#  10  Home Price Index             90 non-null     float64
# dtypes: datetime64[ns](1), float64(5), int64(5)
# memory usage: 7.9 KB

# %%
# Co-relation Matrix
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(),annot = True, cmap='flare' )
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Model Building

# %%
from pycaret import regression

# %%
model_setup=regression.setup(data=df,target='Home Price Index',use_gpu = True)
# Out:
# <style  type="text/css" >
# #T_24cfa_row16_col1,#T_24cfa_row42_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_24cfa_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_24cfa_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_24cfa_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_24cfa_row0_col1" class="data row0 col1" >3781</td>
#             </tr>
#             <tr>
#                         <th id="T_24cfa_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_24cfa_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_24cfa_row1_col1" class="data row1 col1" >Home Price Index</td>
#             </tr>
# ...

# %%
best=regression.compare_models(sort='R2')
# Out:
# <style  type="text/css" >
#     #T_f4d3c_ th {
#           text-align: left;
# ...

# %%
et=regression.create_model('et')
# Out:
# <style  type="text/css" >
# #T_1ad85_row10_col0,#T_1ad85_row10_col1,#T_1ad85_row10_col2,#T_1ad85_row10_col3,#T_1ad85_row10_col4,#T_1ad85_row10_col5{
#             background:  yellow;
#         }</style><table id="T_1ad85_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr>    <tr>        <th class="index_name level0" >Fold</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
from pycaret.regression import plot_model

# %%
plot_model(et, plot = 'feature')

# %% [markdown]
# # Thank You
